# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitmavani/Book-Recommendation-System/blob/main/Book_Recommendation_System_Capstone_Project_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
user_df = pd.read_csv("drive/MyDrive/AlmaBetter/Book Recommendation/Data/Users.csv")
rating_df = pd.read_csv("drive/MyDrive/AlmaBetter/Book Recommendation/Data/Ratings.csv")
book_df = pd.read_csv("drive/MyDrive/AlmaBetter/Book Recommendation/Data/Books.csv")

# %%
user_df.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
rating_df.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
book_df.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
book_df = book_df[['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher']]
book_df.rename(
    columns = {'Book-Title':'title', 'Book-Author':'author', 'Year-Of-Publication':'year', 'Publisher':'publisher'}, 
    inplace=True
    )
user_df.rename(
    columns = {'User-ID':'user_id', 'Location':'location', 'Age':'age'}, 
    inplace=True
    )
rating_df.rename(
    columns = {'User-ID':'user_id', 'Book-Rating':'rating'}, 
    inplace=True
    )

# %%
book_df.head()
# Out:
#          ISBN                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  author  year                   publisher
# 0    Mark P. O. Morford  2002     Oxford University Press
# 1  Richard Bruce Wright  2001       HarperFlamingo Canada
# 2          Carlo D'Este  1991             HarperPerennial
# 3      Gina Bari Kolata  1999        Farrar Straus Giroux
# 4       E. J. W. Barber  1999  W. W. Norton &amp; Company

# %%
user_df.head()
# Out:
#    user_id                            location   age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
rating_df.head()
# Out:
#    user_id        ISBN  rating
# 0   276725  034545104X       0
# 1   276726  0155061224       5
# 2   276727  0446520802       0
# 3   276729  052165615X       3
# 4   276729  0521795028       6

# %%
rating_df["user_id"].value_counts()
# Out:
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 116180        1
# 116166        1
# 116154        1
# 116137        1
# 276723        1
# Name: user_id, Length: 105283, dtype: int64

# %%
user_df.head()
# Out:
#    user_id                            location   age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
data = rating_df["user_id"].value_counts() > 200
data[data].index.shape
# Out:
# (899,)

# %% [markdown]
# # Merge Books And Rating

# %%
rating_books = rating_df.merge(book_df, on='ISBN')
rating_books.head()
# Out:
#    user_id        ISBN  rating                 title      author  year  \
# 0   276725  034545104X       0  Flesh Tones: A Novel  M. J. Rose  2002
# 1     2313  034545104X       5  Flesh Tones: A Novel  M. J. Rose  2002
# 2     6543  034545104X       0  Flesh Tones: A Novel  M. J. Rose  2002
# 3     8680  034545104X       5  Flesh Tones: A Novel  M. J. Rose  2002
# 4    10314  034545104X       9  Flesh Tones: A Novel  M. J. Rose  2002
#
#           publisher
# 0  Ballantine Books
# 1  Ballantine Books
# 2  Ballantine Books
# 3  Ballantine Books
# 4  Ballantine Books

# %%
rating_books.shape
# Out:
# (1031136, 7)

# %%
book_df.shape
# Out:
# (271360, 5)

# %%
book_df["title"].nunique()
# Out:
# 242135

# %%
book_df["ISBN"].nunique()
# Out:
# 271360

# %%
book_df["author"].nunique()
# Out:
# 102023

# %%
rating_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1031136 entries, 0 to 1031135
# Data columns (total 7 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   user_id    1031136 non-null  int64
#  1   ISBN       1031136 non-null  object
#  2   rating     1031136 non-null  int64
#  3   title      1031136 non-null  object
#  4   author     1031135 non-null  object
#  5   year       1031136 non-null  object
#  6   publisher  1031134 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 62.9+ MB

# %%
rating_books.isnull().sum()
# Out:
# user_id      0
# ISBN         0
# rating       0
# title        0
# author       1
# year         0
# publisher    2
# dtype: int64

# %%
user_df.isnull().sum()
# Out:
# user_id          0
# location         0
# age         110762
# dtype: int64

# %%
user_df.shape
# Out:
# (278858, 3)

# %% [markdown]
# ## data analysis(missing value)

# %%
user_df.isnull().sum()
# Out:
# user_id          0
# location         0
# age         110762
# dtype: int64

# %%
book_df.isnull().sum()
# Out:
# ISBN         0
# title        0
# author       1
# year         0
# publisher    2
# dtype: int64

# %%
rating_df.isnull().sum()
# Out:
# user_id    0
# ISBN       0
# rating     0
# dtype: int64

# %% [markdown]
# ### Popurity base recommadation system

# %%
rating_num_df = rating_books.groupby('title').count()['rating'].reset_index()
rating_num_df.rename(columns={'rating':'ratings'},inplace=True)

avg_rating_df = rating_books.groupby('title').mean()['rating'].reset_index()
avg_rating_df.rename(columns={'mean_rating':'ratings'},inplace=True)

popular_df = rating_num_df.merge(avg_rating_df,on='title')
popular_df = popular_df[popular_df['ratings']>=250].sort_values('rating',ascending=False).head(50)
popular_df
# Out:
#                                                     title  ratings    rating
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)      428  5.852804
# 80422        Harry Potter and the Goblet of Fire (Book 4)      387  5.824289
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)      278  5.737410
# 80426   Harry Potter and the Order of the Phoenix (Boo...      347  5.501441
# 80414    Harry Potter and the Chamber of Secrets (Book 2)      556  5.183453
# 191612  The Hobbit : The Enchanting Prelude to The Lor...      281  5.007117
# 187377  The Fellowship of the Ring (The Lord of the Ri...      368  4.948370
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...      575  4.895652
# 211384     The Two Towers (The Lord of the Rings, Part 2)      260  4.880769
# 219741                              To Kill a Mockingbird      510  4.700000
# 183573                                  The Da Vinci Code      898  4.642539
# ...

# %%
rating_books.head()
# Out:
#    user_id        ISBN  rating                 title      author  year  \
# 0   276725  034545104X       0  Flesh Tones: A Novel  M. J. Rose  2002
# 1     2313  034545104X       5  Flesh Tones: A Novel  M. J. Rose  2002
# 2     6543  034545104X       0  Flesh Tones: A Novel  M. J. Rose  2002
# 3     8680  034545104X       5  Flesh Tones: A Novel  M. J. Rose  2002
# 4    10314  034545104X       9  Flesh Tones: A Novel  M. J. Rose  2002
#
#           publisher
# 0  Ballantine Books
# 1  Ballantine Books
# 2  Ballantine Books
# 3  Ballantine Books
# 4  Ballantine Books
